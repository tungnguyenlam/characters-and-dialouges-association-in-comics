# %%
# !ls
# %cd ../..
# !ls
# Now you should see the characters-and-dialouges-association-in-comics directory

# %%
import os
import subprocess
from pathlib import Path

END_WITH_LOCAL = 'characters-and-dialouges-association-in-comics'

os.environ['PATH'] = f"/root/.cargo/bin:{os.environ['PATH']}"

BASE_DIR = str(Path(os.getcwd()).parent.parent)
print(f"BASE_DIR: {BASE_DIR}")

# Simple validation
if not (BASE_DIR.endswith('/content') or BASE_DIR.endswith(END_WITH_LOCAL)):
    raise ValueError(f"Expected to be in .../{END_WITH_LOCAL} or .../content directory, but got: {BASE_DIR}")
# Out:
# BASE_DIR: e:\B3\group_prj\characters-and-dialouges-association-in-comics

# %%
import os
os.environ["PYTORCH_ENABLE_MPS_FALLBACK"] = "1"

import torch
if torch.cuda.is_available():
    device = torch.device("cuda")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
import os
import json
import xml.etree.ElementTree as ET
from tqdm import tqdm
import random

# --- Configuration ---
base_path = os.path.join(BASE_DIR, "data", "Manga109", "Human_Annotate_300")
annotations_dir = os.path.join(base_path, "annotations_xml")
CATEGORIES_TO_DETECT = ["bubble"]
VAL_SPLIT_RATIO = 0.2  # Use 20% of the data for validation

def process_books(book_list, output_filename):
    """Processes a list of books and saves them to a COCO JSON file."""
    
    # Category mapping (IDs should start from 1)
    categories_coco = [{"id": i, "name": name} for i, name in enumerate(CATEGORIES_TO_DETECT, start=1)]
    category_map = {name: i for i, name in enumerate(CATEGORIES_TO_DETECT, start=1)}
    
    coco_output = {
        "info": {
            "description": "Manga109 Dataset for Detectron2",
            "version": "1.0",
        },
        "licenses": [],
        "images": [],
        "annotations": [],
        "categories": categories_coco
    }
    
    annotation_id_counter = 1
    image_id_counter = 1
    
    print(f"Processing {len(book_list)} books for '{output_filename}'...")
    for book in tqdm(book_list, desc=f"Processing for {output_filename}"):
        xml_file_path = os.path.join(annotations_dir, f"{book}.xml")
        
        tree = ET.parse(xml_file_path)
        root = tree.getroot()
        
        for page in root.findall(".//page"):
            page_index = page.attrib['index']
            image_width = int(page.attrib['width'])
            image_height = int(page.attrib['height'])
            
            if image_width == 0 or image_height == 0:
                continue
            
            image_rel_path = os.path.join(book, f"{page_index.zfill(3)}.jpg")
            
            image_info = {
                "id": image_id_counter,
                "file_name": image_rel_path,
                "width": image_width,
                "height": image_height,
            }
            coco_output["images"].append(image_info)

            for category_name in CATEGORIES_TO_DETECT:
                for obj in page.findall(category_name):
                    bbox = obj.attrib
                    xmin = int(bbox['xmin'])
                    ymin = int(bbox['ymin'])
                    width = int(bbox['xmax']) - xmin
                    height = int(bbox['ymax']) - ymin
                    
                    annotation_info = {
                        "id": annotation_id_counter,
                        "image_id": image_id_counter,
                        "category_id": category_map[category_name],
                        "bbox": [xmin, ymin, width, height],
                        "area": width * height,
                        "iscrowd": 0,
                    }
                    coco_output["annotations"].append(annotation_info)
                    annotation_id_counter += 1
            
            image_id_counter += 1

    output_json_path = os.path.join(base_path, output_filename)
    with open(output_json_path, 'w') as f:
        json.dump(coco_output, f)
        
    print(f"\nConversion complete! File saved to: {output_json_path}")
    return output_json_path

SEED = 42
random.seed(SEED)

if __name__ == '__main__':
    all_books = [f.replace('.xml', '') for f in os.listdir(annotations_dir) if f.endswith('.xml')]
    random.shuffle(all_books) # Shuffle for a random split

    split_index = int(len(all_books) * VAL_SPLIT_RATIO)
    val_books = all_books[:split_index]
    train_books = all_books[split_index:]
    
    print(f"Total books: {len(all_books)}. Training books: {len(train_books)}. Validation books: {len(val_books)}.")

    # Process and save the training and validation sets
    process_books(train_books, "train.json")
    process_books(val_books, "val.json")
# Out:
# Total books: 35. Training books: 28. Validation books: 7.
# Processing 28 books for 'train.json'...
# Processing for train.json: 100%|██████████| 28/28 [00:00<00:00, 131.43it/s]
# Conversion complete! File saved to: e:\B3\group_prj\characters-and-dialouges-association-in-comics\data\Manga109\Human_Annotate_300\train.json
# Processing 7 books for 'val.json'...
# Processing for val.json: 100%|██████████| 7/7 [00:00<00:00, 291.64it/s]
# Conversion complete! File saved to: e:\B3\group_prj\characters-and-dialouges-association-in-comics\data\Manga109\Human_Annotate_300\val.json

# %%
from detectron2.data.datasets import register_coco_instances
from detectron2.data import DatasetCatalog, MetadataCatalog
import random
import cv2
from detectron2.utils.visualizer import Visualizer
import matplotlib.pyplot as plt

# --- Paths ---
base_path = os.path.join(BASE_DIR, "data", "Manga109", "Human_Annotate_300")
images_dir = os.path.join(base_path, "train")
train_json_path = os.path.join(base_path, "train.json")
val_json_path = os.path.join(base_path, "val.json")
CATEGORIES_TO_DETECT = ["bubble"]

# --- Register the dataset ---
# The first argument is the name you will use to refer to this dataset.
# Register the training dataset
register_coco_instances("manga109_train", {}, train_json_path, images_dir)

# Register the validation dataset
register_coco_instances("manga109_val", {}, val_json_path, images_dir)

# %%
from detectron2.engine import DefaultTrainer
from detectron2 import model_zoo
from detectron2.config import get_cfg

# --- Configuration Setup ---
cfg = get_cfg()

# Start with a pre-trained model. Faster R-CNN is a good choice.
# Find more models in the Detectron2 Model Zoo: https://github.com/facebookresearch/detectron2/blob/main/MODEL_ZOO.md
cfg.merge_from_file(model_zoo.get_config_file("COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml"))

# cfg.MODEL.WEIGHTS = os.path.join(BASE_DIR, "models/bubble-detection/detectron2/model_final_280758.pkl")
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml")

cfg.MODEL.DEVICE = str(device)

# --- Dataset Configuration ---
cfg.DATASETS.TRAIN = ("manga109_train",)
# --- ADD THE TEST DATASET ---
cfg.DATASETS.TEST = ("manga109_val",) 
# ----------------------------

# --- Evaluation Configuration ---
# How often to run evaluation (in number of iterations).
cfg.TEST.EVAL_PERIOD = 500 
# --------------------------------

cfg.DATALOADER.NUM_WORKERS = 2 # 12
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 128
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 1  # bubble

cfg.SOLVER.IMS_PER_BATCH = 2 # 8
cfg.SOLVER.BASE_LR = 0.0025
cfg.SOLVER.MAX_ITER = 3000 
cfg.SOLVER.STEPS = []

cfg.OUTPUT_DIR = os.path.join(BASE_DIR, "models", "bubble-detection","detectron2")
os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)

# --- Start Training ---
trainer = DefaultTrainer(cfg)
trainer.resume_or_load(resume=False)
trainer.train()
# Out:
# [10/02 11:38:33 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=2, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=4, bias=True)
#     )
#   )
# )
# [10/02 11:38:33 d2.data.datasets.coco]: Loaded 210 images in COCO format from e:\B3\group_prj\characters-and-dialouges-association-in-comics\data\Manga109\Human_Annotate_300\train.json
# [10/02 11:38:33 d2.data.build]: Removed 46 images with no usable annotations. 164 images left.
# [10/02 11:38:33 d2.data.build]: Distribution of instances among all 1 categories:
# |  category  | #instances   |
# |:----------:|:-------------|
# |   bubble   | 2147         |
# |            |              |
# [10/02 11:38:33 d2.data.datasets.coco]: Loaded 210 images in COCO format from e:\B3\group_prj\characters-and-dialouges-association-in-comics\data\Manga109\Human_Annotate_300\train.json
# [10/02 11:38:33 d2.data.build]: Removed 46 images with no usable annotations. 164 images left.
# [10/02 11:38:33 d2.data.build]: Distribution of instances among all 1 categories:
# |  category  | #instances   |
# |:----------:|:-------------|
# |   bubble   | 2147         |
# |            |              |
# [10/02 11:38:33 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [10/02 11:38:33 d2.data.build]: Using training sampler TrainingSampler
# [10/02 11:38:33 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/02 11:38:33 d2.data.common]: Serializing 164 elements to byte tensors and concatenating them all ...
# [10/02 11:38:33 d2.data.common]: Serialized dataset takes 0.11 MiB
# [10/02 11:38:33 d2.data.build]: Making batched data loader with batch_size=2
# [10/02 11:38:33 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-Detection/faster_rcnn_R_50_FPN_3x/137849458/model_final_280758.pkl ...
# [10/02 11:38:33 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [10/02 11:38:33 d2.data.build]: Using training sampler TrainingSampler
# [10/02 11:38:33 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/02 11:38:33 d2.data.common]: Serializing 164 elements to byte tensors and concatenating them all ...
# [10/02 11:38:33 d2.data.common]: Serialized dataset takes 0.11 MiB
# [10/02 11:38:33 d2.data.build]: Making batched data loader with batch_size=2
# [10/02 11:38:33 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-Detection/faster_rcnn_R_50_FPN_3x/137849458/model_final_280758.pkl ...
# Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (2, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (2,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (4, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (4,) in the model! You might want to double check if this is expected.
# Some model parameters or buffers are not found in the checkpoint:
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (2,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (4, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (4,) in the model! You might want to double check if this is expected.
# Some model parameters or buffers are not found in the checkpoint:
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# [10/02 11:38:33 d2.engine.train_loop]: Starting training from iteration 0
# d:\anaconda\envs\cv\lib\site-packages\torch\functional.py:554: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\aten\src\ATen\native\TensorShape.cpp:4324.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [10/02 11:38:56 d2.utils.events]:  eta: 0:49:16  iter: 19  total_loss: 1.559  loss_cls: 0.6039  loss_box_reg: 0.5671  loss_rpn_cls: 0.3001  loss_rpn_loc: 0.07918    time: 0.9445  last_time: 0.6093  data_time: 0.2221  last_data_time: 0.0012   lr: 4.9952e-05  max_mem: 2318M
# [10/02 11:39:17 d2.utils.events]:  eta: 0:52:10  iter: 39  total_loss: 1.428  loss_cls: 0.5466  loss_box_reg: 0.7295  loss_rpn_cls: 0.07435  loss_rpn_loc: 0.05867    time: 0.9677  last_time: 1.1597  data_time: 0.0019  last_data_time: 0.0026   lr: 9.9902e-05  max_mem: 2320M
# [10/02 11:39:17 d2.utils.events]:  eta: 0:52:10  iter: 39  total_loss: 1.428  loss_cls: 0.5466  loss_box_reg: 0.7295  loss_rpn_cls: 0.07435  loss_rpn_loc: 0.05867    time: 0.9677  last_time: 1.1597  data_time: 0.0019  last_data_time: 0.0026   lr: 9.9902e-05  max_mem: 2320M
# [10/02 11:39:33 d2.utils.events]:  eta: 0:48:14  iter: 59  total_loss: 1.333  loss_cls: 0.4762  loss_box_reg: 0.738  loss_rpn_cls: 0.06864  loss_rpn_loc: 0.04801    time: 0.9152  last_time: 0.7223  data_time: 0.0019  last_data_time: 0.0013   lr: 0.00014985  max_mem: 2320M
# [10/02 11:39:33 d2.utils.events]:  eta: 0:48:14  iter: 59  total_loss: 1.333  loss_cls: 0.4762  loss_box_reg: 0.738  loss_rpn_cls: 0.06864  loss_rpn_loc: 0.04801    time: 0.9152  last_time: 0.7223  data_time: 0.0019  last_data_time: 0.0013   lr: 0.00014985  max_mem: 2320M
# [10/02 11:39:52 d2.utils.events]:  eta: 0:50:28  iter: 79  total_loss: 1.208  loss_cls: 0.3863  loss_box_reg: 0.721  loss_rpn_cls: 0.05307  loss_rpn_loc: 0.03842    time: 0.9204  last_time: 1.1352  data_time: 0.0019  last_data_time: 0.0025   lr: 0.0001998  max_mem: 2320M
# [10/02 11:39:52 d2.utils.events]:  eta: 0:50:28  iter: 79  total_loss: 1.208  loss_cls: 0.3863  loss_box_reg: 0.721  loss_rpn_cls: 0.05307  loss_rpn_loc: 0.03842    time: 0.9204  last_time: 1.1352  data_time: 0.0019  last_data_time: 0.0025   lr: 0.0001998  max_mem: 2320M
# [10/02 11:40:10 d2.utils.events]:  eta: 0:50:23  iter: 99  total_loss: 1.031  loss_cls: 0.3141  loss_box_reg: 0.6458  loss_rpn_cls: 0.04179  loss_rpn_loc: 0.04579    time: 0.9213  last_time: 1.1246  data_time: 0.0015  last_data_time: 0.0015   lr: 0.00024975  max_mem: 2320M
# [10/02 11:40:10 d2.utils.events]:  eta: 0:50:23  iter: 99  total_loss: 1.031  loss_cls: 0.3141  loss_box_reg: 0.6458  loss_rpn_cls: 0.04179  loss_rpn_loc: 0.04579    time: 0.9213  last_time: 1.1246  data_time: 0.0015  last_data_time: 0.0015   lr: 0.00024975  max_mem: 2320M
# [10/02 11:40:30 d2.utils.events]:  eta: 0:50:08  iter: 119  total_loss: 0.9233  loss_cls: 0.2656  loss_box_reg: 0.5472  loss_rpn_cls: 0.03201  loss_rpn_loc: 0.04071    time: 0.9343  last_time: 1.1367  data_time: 0.0015  last_data_time: 0.0017   lr: 0.0002997  max_mem: 2320M
# [10/02 11:40:30 d2.utils.events]:  eta: 0:50:08  iter: 119  total_loss: 0.9233  loss_cls: 0.2656  loss_box_reg: 0.5472  loss_rpn_cls: 0.03201  loss_rpn_loc: 0.04071    time: 0.9343  last_time: 1.1367  data_time: 0.0015  last_data_time: 0.0017   lr: 0.0002997  max_mem: 2320M
# [10/02 11:40:50 d2.utils.events]:  eta: 0:49:56  iter: 139  total_loss: 0.6974  loss_cls: 0.2058  loss_box_reg: 0.4142  loss_rpn_cls: 0.03161  loss_rpn_loc: 0.04089    time: 0.9472  last_time: 1.1361  data_time: 0.0015  last_data_time: 0.0014   lr: 0.00034965  max_mem: 2320M
# [10/02 11:40:50 d2.utils.events]:  eta: 0:49:56  iter: 139  total_loss: 0.6974  loss_cls: 0.2058  loss_box_reg: 0.4142  loss_rpn_cls: 0.03161  loss_rpn_loc: 0.04089    time: 0.9472  last_time: 1.1361  data_time: 0.0015  last_data_time: 0.0014   lr: 0.00034965  max_mem: 2320M
# [10/02 11:41:11 d2.utils.events]:  eta: 0:49:37  iter: 159  total_loss: 0.5595  loss_cls: 0.1752  loss_box_reg: 0.3062  loss_rpn_cls: 0.02348  loss_rpn_loc: 0.04027    time: 0.9559  last_time: 1.0437  data_time: 0.0015  last_data_time: 0.0015   lr: 0.0003996  max_mem: 2320M
# [10/02 11:41:11 d2.utils.events]:  eta: 0:49:37  iter: 159  total_loss: 0.5595  loss_cls: 0.1752  loss_box_reg: 0.3062  loss_rpn_cls: 0.02348  loss_rpn_loc: 0.04027    time: 0.9559  last_time: 1.0437  data_time: 0.0015  last_data_time: 0.0015   lr: 0.0003996  max_mem: 2320M
# [10/02 11:41:29 d2.utils.events]:  eta: 0:49:14  iter: 179  total_loss: 0.5182  loss_cls: 0.1631  loss_box_reg: 0.2973  loss_rpn_cls: 0.02188  loss_rpn_loc: 0.03576    time: 0.9483  last_time: 0.6648  data_time: 0.0016  last_data_time: 0.0015   lr: 0.00044955  max_mem: 2320M
# [10/02 11:41:29 d2.utils.events]:  eta: 0:49:14  iter: 179  total_loss: 0.5182  loss_cls: 0.1631  loss_box_reg: 0.2973  loss_rpn_cls: 0.02188  loss_rpn_loc: 0.03576    time: 0.9483  last_time: 0.6648  data_time: 0.0016  last_data_time: 0.0015   lr: 0.00044955  max_mem: 2320M
# [10/02 11:41:49 d2.utils.events]:  eta: 0:48:55  iter: 199  total_loss: 0.4369  loss_cls: 0.1414  loss_box_reg: 0.2503  loss_rpn_cls: 0.01189  loss_rpn_loc: 0.03353    time: 0.9538  last_time: 1.0485  data_time: 0.0015  last_data_time: 0.0011   lr: 0.0004995  max_mem: 2320M
# [10/02 11:41:49 d2.utils.events]:  eta: 0:48:55  iter: 199  total_loss: 0.4369  loss_cls: 0.1414  loss_box_reg: 0.2503  loss_rpn_cls: 0.01189  loss_rpn_loc: 0.03353    time: 0.9538  last_time: 1.0485  data_time: 0.0015  last_data_time: 0.0011   lr: 0.0004995  max_mem: 2320M
# [10/02 11:42:09 d2.utils.events]:  eta: 0:48:43  iter: 219  total_loss: 0.3823  loss_cls: 0.1222  loss_box_reg: 0.2156  loss_rpn_cls: 0.009071  loss_rpn_loc: 0.03142    time: 0.9613  last_time: 0.7042  data_time: 0.0017  last_data_time: 0.0016   lr: 0.00054945  max_mem: 2320M
# [10/02 11:42:09 d2.utils.events]:  eta: 0:48:43  iter: 219  total_loss: 0.3823  loss_cls: 0.1222  loss_box_reg: 0.2156  loss_rpn_cls: 0.009071  loss_rpn_loc: 0.03142    time: 0.9613  last_time: 0.7042  data_time: 0.0017  last_data_time: 0.0016   lr: 0.00054945  max_mem: 2320M
# [10/02 11:42:29 d2.utils.events]:  eta: 0:48:27  iter: 239  total_loss: 0.4262  loss_cls: 0.1397  loss_box_reg: 0.239  loss_rpn_cls: 0.01313  loss_rpn_loc: 0.03013    time: 0.9612  last_time: 0.7410  data_time: 0.0017  last_data_time: 0.0012   lr: 0.0005994  max_mem: 2320M
# [10/02 11:42:29 d2.utils.events]:  eta: 0:48:27  iter: 239  total_loss: 0.4262  loss_cls: 0.1397  loss_box_reg: 0.239  loss_rpn_cls: 0.01313  loss_rpn_loc: 0.03013    time: 0.9612  last_time: 0.7410  data_time: 0.0017  last_data_time: 0.0012   lr: 0.0005994  max_mem: 2320M
# [10/02 11:42:47 d2.utils.events]:  eta: 0:48:05  iter: 259  total_loss: 0.4118  loss_cls: 0.1252  loss_box_reg: 0.2277  loss_rpn_cls: 0.0133  loss_rpn_loc: 0.03106    time: 0.9587  last_time: 1.1901  data_time: 0.0017  last_data_time: 0.0043   lr: 0.00064935  max_mem: 2320M
# [10/02 11:42:47 d2.utils.events]:  eta: 0:48:05  iter: 259  total_loss: 0.4118  loss_cls: 0.1252  loss_box_reg: 0.2277  loss_rpn_cls: 0.0133  loss_rpn_loc: 0.03106    time: 0.9587  last_time: 1.1901  data_time: 0.0017  last_data_time: 0.0043   lr: 0.00064935  max_mem: 2320M
# [10/02 11:43:07 d2.utils.events]:  eta: 0:47:44  iter: 279  total_loss: 0.3836  loss_cls: 0.1089  loss_box_reg: 0.1955  loss_rpn_cls: 0.01312  loss_rpn_loc: 0.03518    time: 0.9592  last_time: 0.7294  data_time: 0.0016  last_data_time: 0.0015   lr: 0.0006993  max_mem: 2320M
# [10/02 11:43:07 d2.utils.events]:  eta: 0:47:44  iter: 279  total_loss: 0.3836  loss_cls: 0.1089  loss_box_reg: 0.1955  loss_rpn_cls: 0.01312  loss_rpn_loc: 0.03518    time: 0.9592  last_time: 0.7294  data_time: 0.0016  last_data_time: 0.0015   lr: 0.0006993  max_mem: 2320M
# [10/02 11:43:24 d2.utils.events]:  eta: 0:47:19  iter: 299  total_loss: 0.3906  loss_cls: 0.1057  loss_box_reg: 0.2168  loss_rpn_cls: 0.006959  loss_rpn_loc: 0.03973    time: 0.9547  last_time: 1.0541  data_time: 0.0014  last_data_time: 0.0016   lr: 0.00074925  max_mem: 2320M
# [10/02 11:43:24 d2.utils.events]:  eta: 0:47:19  iter: 299  total_loss: 0.3906  loss_cls: 0.1057  loss_box_reg: 0.2168  loss_rpn_cls: 0.006959  loss_rpn_loc: 0.03973    time: 0.9547  last_time: 1.0541  data_time: 0.0014  last_data_time: 0.0016   lr: 0.00074925  max_mem: 2320M
# [10/02 11:43:43 d2.utils.events]:  eta: 0:46:57  iter: 319  total_loss: 0.3974  loss_cls: 0.1478  loss_box_reg: 0.2047  loss_rpn_cls: 0.006166  loss_rpn_loc: 0.03227    time: 0.9541  last_time: 1.1221  data_time: 0.0016  last_data_time: 0.0013   lr: 0.0007992  max_mem: 2320M
# [10/02 11:43:43 d2.utils.events]:  eta: 0:46:57  iter: 319  total_loss: 0.3974  loss_cls: 0.1478  loss_box_reg: 0.2047  loss_rpn_cls: 0.006166  loss_rpn_loc: 0.03227    time: 0.9541  last_time: 1.1221  data_time: 0.0016  last_data_time: 0.0013   lr: 0.0007992  max_mem: 2320M
# [10/02 11:44:03 d2.utils.events]:  eta: 0:46:36  iter: 339  total_loss: 0.3559  loss_cls: 0.1058  loss_box_reg: 0.219  loss_rpn_cls: 0.01019  loss_rpn_loc: 0.02803    time: 0.9554  last_time: 0.7337  data_time: 0.0015  last_data_time: 0.0013   lr: 0.00084915  max_mem: 2320M
# [10/02 11:44:03 d2.utils.events]:  eta: 0:46:36  iter: 339  total_loss: 0.3559  loss_cls: 0.1058  loss_box_reg: 0.219  loss_rpn_cls: 0.01019  loss_rpn_loc: 0.02803    time: 0.9554  last_time: 0.7337  data_time: 0.0015  last_data_time: 0.0013   lr: 0.00084915  max_mem: 2320M
# [10/02 11:44:21 d2.utils.events]:  eta: 0:46:15  iter: 359  total_loss: 0.3638  loss_cls: 0.1024  loss_box_reg: 0.2065  loss_rpn_cls: 0.005806  loss_rpn_loc: 0.02961    time: 0.9527  last_time: 1.1492  data_time: 0.0014  last_data_time: 0.0013   lr: 0.0008991  max_mem: 2320M
# [10/02 11:44:21 d2.utils.events]:  eta: 0:46:15  iter: 359  total_loss: 0.3638  loss_cls: 0.1024  loss_box_reg: 0.2065  loss_rpn_cls: 0.005806  loss_rpn_loc: 0.02961    time: 0.9527  last_time: 1.1492  data_time: 0.0014  last_data_time: 0.0013   lr: 0.0008991  max_mem: 2320M
# [10/02 11:44:39 d2.utils.events]:  eta: 0:45:51  iter: 379  total_loss: 0.3286  loss_cls: 0.1102  loss_box_reg: 0.1906  loss_rpn_cls: 0.006465  loss_rpn_loc: 0.0299    time: 0.9488  last_time: 1.1483  data_time: 0.0015  last_data_time: 0.0016   lr: 0.00094905  max_mem: 2320M
# [10/02 11:44:39 d2.utils.events]:  eta: 0:45:51  iter: 379  total_loss: 0.3286  loss_cls: 0.1102  loss_box_reg: 0.1906  loss_rpn_cls: 0.006465  loss_rpn_loc: 0.0299    time: 0.9488  last_time: 1.1483  data_time: 0.0015  last_data_time: 0.0016   lr: 0.00094905  max_mem: 2320M
# [10/02 11:44:57 d2.utils.events]:  eta: 0:45:29  iter: 399  total_loss: 0.3379  loss_cls: 0.1135  loss_box_reg: 0.2026  loss_rpn_cls: 0.008534  loss_rpn_loc: 0.02739    time: 0.9480  last_time: 0.7301  data_time: 0.0015  last_data_time: 0.0015   lr: 0.000999  max_mem: 2320M
# [10/02 11:44:57 d2.utils.events]:  eta: 0:45:29  iter: 399  total_loss: 0.3379  loss_cls: 0.1135  loss_box_reg: 0.2026  loss_rpn_cls: 0.008534  loss_rpn_loc: 0.02739    time: 0.9480  last_time: 0.7301  data_time: 0.0015  last_data_time: 0.0015   lr: 0.000999  max_mem: 2320M
# [10/02 11:45:15 d2.utils.events]:  eta: 0:45:06  iter: 419  total_loss: 0.3544  loss_cls: 0.1047  loss_box_reg: 0.1902  loss_rpn_cls: 0.007549  loss_rpn_loc: 0.02447    time: 0.9461  last_time: 0.7435  data_time: 0.0015  last_data_time: 0.0015   lr: 0.001049  max_mem: 2320M
# [10/02 11:45:15 d2.utils.events]:  eta: 0:45:06  iter: 419  total_loss: 0.3544  loss_cls: 0.1047  loss_box_reg: 0.1902  loss_rpn_cls: 0.007549  loss_rpn_loc: 0.02447    time: 0.9461  last_time: 0.7435  data_time: 0.0015  last_data_time: 0.0015   lr: 0.001049  max_mem: 2320M
# [10/02 11:45:32 d2.utils.events]:  eta: 0:44:44  iter: 439  total_loss: 0.3076  loss_cls: 0.0884  loss_box_reg: 0.1829  loss_rpn_cls: 0.007  loss_rpn_loc: 0.03017    time: 0.9417  last_time: 0.7356  data_time: 0.0015  last_data_time: 0.0014   lr: 0.0010989  max_mem: 2320M
# [10/02 11:45:32 d2.utils.events]:  eta: 0:44:44  iter: 439  total_loss: 0.3076  loss_cls: 0.0884  loss_box_reg: 0.1829  loss_rpn_cls: 0.007  loss_rpn_loc: 0.03017    time: 0.9417  last_time: 0.7356  data_time: 0.0015  last_data_time: 0.0014   lr: 0.0010989  max_mem: 2320M
# [10/02 11:45:50 d2.utils.events]:  eta: 0:44:22  iter: 459  total_loss: 0.3609  loss_cls: 0.1067  loss_box_reg: 0.1977  loss_rpn_cls: 0.004224  loss_rpn_loc: 0.03019    time: 0.9385  last_time: 0.6614  data_time: 0.0014  last_data_time: 0.0013   lr: 0.0011489  max_mem: 2320M
# [10/02 11:45:50 d2.utils.events]:  eta: 0:44:22  iter: 459  total_loss: 0.3609  loss_cls: 0.1067  loss_box_reg: 0.1977  loss_rpn_cls: 0.004224  loss_rpn_loc: 0.03019    time: 0.9385  last_time: 0.6614  data_time: 0.0014  last_data_time: 0.0013   lr: 0.0011489  max_mem: 2320M
# [10/02 11:46:08 d2.utils.events]:  eta: 0:44:00  iter: 479  total_loss: 0.3396  loss_cls: 0.09733  loss_box_reg: 0.1855  loss_rpn_cls: 0.00407  loss_rpn_loc: 0.02853    time: 0.9366  last_time: 1.1560  data_time: 0.0015  last_data_time: 0.0014   lr: 0.0011988  max_mem: 2320M
# [10/02 11:46:08 d2.utils.events]:  eta: 0:44:00  iter: 479  total_loss: 0.3396  loss_cls: 0.09733  loss_box_reg: 0.1855  loss_rpn_cls: 0.00407  loss_rpn_loc: 0.02853    time: 0.9366  last_time: 1.1560  data_time: 0.0015  last_data_time: 0.0014   lr: 0.0011988  max_mem: 2320M
# [10/02 11:46:25 d2.data.datasets.coco]: Loaded 60 images in COCO format from e:\B3\group_prj\characters-and-dialouges-association-in-comics\data\Manga109\Human_Annotate_300\val.json
# [10/02 11:46:25 d2.data.build]: Distribution of instances among all 1 categories:
# |  category  | #instances   |
# |:----------:|:-------------|
# |   bubble   | 528          |
# |            |              |
# [10/02 11:46:25 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [10/02 11:46:25 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/02 11:46:25 d2.data.common]: Serializing 60 elements to byte tensors and concatenating them all ...
# [10/02 11:46:25 d2.data.common]: Serialized dataset takes 0.03 MiB
# WARNING [10/02 11:46:25 d2.engine.defaults]: No evaluator found. Use `DefaultTrainer.test(evaluators=)`, or implement its `build_evaluator` method.
# [10/02 11:46:25 d2.data.datasets.coco]: Loaded 60 images in COCO format from e:\B3\group_prj\characters-and-dialouges-association-in-comics\data\Manga109\Human_Annotate_300\val.json
# [10/02 11:46:25 d2.data.build]: Distribution of instances among all 1 categories:
# |  category  | #instances   |
# |:----------:|:-------------|
# |   bubble   | 528          |
# |            |              |
# [10/02 11:46:25 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [10/02 11:46:25 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/02 11:46:25 d2.data.common]: Serializing 60 elements to byte tensors and concatenating them all ...
# [10/02 11:46:25 d2.data.common]: Serialized dataset takes 0.03 MiB
# WARNING [10/02 11:46:25 d2.engine.defaults]: No evaluator found. Use `DefaultTrainer.test(evaluators=)`, or implement its `build_evaluator` method.
# [10/02 11:46:25 d2.utils.events]:  eta: 0:43:37  iter: 499  total_loss: 0.3787  loss_cls: 0.1195  loss_box_reg: 0.2074  loss_rpn_cls: 0.006021  loss_rpn_loc: 0.03671    time: 0.9332  last_time: 1.0392  data_time: 0.0015  last_data_time: 0.0014   lr: 0.0012488  max_mem: 2320M
# [10/02 11:46:25 d2.utils.events]:  eta: 0:43:37  iter: 499  total_loss: 0.3787  loss_cls: 0.1195  loss_box_reg: 0.2074  loss_rpn_cls: 0.006021  loss_rpn_loc: 0.03671    time: 0.9332  last_time: 1.0392  data_time: 0.0015  last_data_time: 0.0014   lr: 0.0012488  max_mem: 2320M
# [10/02 11:46:42 d2.utils.events]:  eta: 0:43:14  iter: 519  total_loss: 0.2954  loss_cls: 0.08792  loss_box_reg: 0.1829  loss_rpn_cls: 0.002802  loss_rpn_loc: 0.02462    time: 0.9295  last_time: 0.5668  data_time: 0.0015  last_data_time: 0.0014   lr: 0.0012987  max_mem: 2320M
# [10/02 11:46:42 d2.utils.events]:  eta: 0:43:14  iter: 519  total_loss: 0.2954  loss_cls: 0.08792  loss_box_reg: 0.1829  loss_rpn_cls: 0.002802  loss_rpn_loc: 0.02462    time: 0.9295  last_time: 0.5668  data_time: 0.0015  last_data_time: 0.0014   lr: 0.0012987  max_mem: 2320M
# [10/02 11:47:01 d2.utils.events]:  eta: 0:42:55  iter: 539  total_loss: 0.3836  loss_cls: 0.1169  loss_box_reg: 0.2119  loss_rpn_cls: 0.004727  loss_rpn_loc: 0.02852    time: 0.9308  last_time: 1.1519  data_time: 0.0015  last_data_time: 0.0014   lr: 0.0013487  max_mem: 2320M
# [10/02 11:47:01 d2.utils.events]:  eta: 0:42:55  iter: 539  total_loss: 0.3836  loss_cls: 0.1169  loss_box_reg: 0.2119  loss_rpn_cls: 0.004727  loss_rpn_loc: 0.02852    time: 0.9308  last_time: 1.1519  data_time: 0.0015  last_data_time: 0.0014   lr: 0.0013487  max_mem: 2320M
# [10/02 11:47:18 d2.utils.events]:  eta: 0:42:33  iter: 559  total_loss: 0.3192  loss_cls: 0.09107  loss_box_reg: 0.1888  loss_rpn_cls: 0.007119  loss_rpn_loc: 0.02564    time: 0.9278  last_time: 0.6679  data_time: 0.0014  last_data_time: 0.0014   lr: 0.0013986  max_mem: 2320M
# [10/02 11:47:18 d2.utils.events]:  eta: 0:42:33  iter: 559  total_loss: 0.3192  loss_cls: 0.09107  loss_box_reg: 0.1888  loss_rpn_cls: 0.007119  loss_rpn_loc: 0.02564    time: 0.9278  last_time: 0.6679  data_time: 0.0014  last_data_time: 0.0014   lr: 0.0013986  max_mem: 2320M
# [10/02 11:47:37 d2.utils.events]:  eta: 0:42:13  iter: 579  total_loss: 0.3019  loss_cls: 0.1172  loss_box_reg: 0.172  loss_rpn_cls: 0.004209  loss_rpn_loc: 0.02827    time: 0.9293  last_time: 1.1381  data_time: 0.0015  last_data_time: 0.0014   lr: 0.0014486  max_mem: 2320M
# [10/02 11:47:37 d2.utils.events]:  eta: 0:42:13  iter: 579  total_loss: 0.3019  loss_cls: 0.1172  loss_box_reg: 0.172  loss_rpn_cls: 0.004209  loss_rpn_loc: 0.02827    time: 0.9293  last_time: 1.1381  data_time: 0.0015  last_data_time: 0.0014   lr: 0.0014486  max_mem: 2320M
# [10/02 11:47:56 d2.utils.events]:  eta: 0:41:53  iter: 599  total_loss: 0.3541  loss_cls: 0.1106  loss_box_reg: 0.2061  loss_rpn_cls: 0.004787  loss_rpn_loc: 0.03333    time: 0.9304  last_time: 1.1414  data_time: 0.0015  last_data_time: 0.0013   lr: 0.0014985  max_mem: 2320M
# [10/02 11:47:56 d2.utils.events]:  eta: 0:41:53  iter: 599  total_loss: 0.3541  loss_cls: 0.1106  loss_box_reg: 0.2061  loss_rpn_cls: 0.004787  loss_rpn_loc: 0.03333    time: 0.9304  last_time: 1.1414  data_time: 0.0015  last_data_time: 0.0013   lr: 0.0014985  max_mem: 2320M
# [10/02 11:48:15 d2.utils.events]:  eta: 0:41:32  iter: 619  total_loss: 0.3094  loss_cls: 0.08586  loss_box_reg: 0.173  loss_rpn_cls: 0.003919  loss_rpn_loc: 0.02877    time: 0.9298  last_time: 1.0483  data_time: 0.0015  last_data_time: 0.0015   lr: 0.0015485  max_mem: 2320M
# [10/02 11:48:15 d2.utils.events]:  eta: 0:41:32  iter: 619  total_loss: 0.3094  loss_cls: 0.08586  loss_box_reg: 0.173  loss_rpn_cls: 0.003919  loss_rpn_loc: 0.02877    time: 0.9298  last_time: 1.0483  data_time: 0.0015  last_data_time: 0.0015   lr: 0.0015485  max_mem: 2320M
# [10/02 11:48:34 d2.utils.events]:  eta: 0:41:11  iter: 639  total_loss: 0.3008  loss_cls: 0.1049  loss_box_reg: 0.1719  loss_rpn_cls: 0.002314  loss_rpn_loc: 0.0245    time: 0.9306  last_time: 1.1446  data_time: 0.0016  last_data_time: 0.0015   lr: 0.0015984  max_mem: 2320M
# [10/02 11:48:34 d2.utils.events]:  eta: 0:41:11  iter: 639  total_loss: 0.3008  loss_cls: 0.1049  loss_box_reg: 0.1719  loss_rpn_cls: 0.002314  loss_rpn_loc: 0.0245    time: 0.9306  last_time: 1.1446  data_time: 0.0016  last_data_time: 0.0015   lr: 0.0015984  max_mem: 2320M
# [10/02 11:48:54 d2.utils.events]:  eta: 0:40:50  iter: 659  total_loss: 0.2995  loss_cls: 0.08161  loss_box_reg: 0.1836  loss_rpn_cls: 0.003455  loss_rpn_loc: 0.02393    time: 0.9325  last_time: 1.3536  data_time: 0.0015  last_data_time: 0.0015   lr: 0.0016484  max_mem: 2320M
# [10/02 11:48:54 d2.utils.events]:  eta: 0:40:50  iter: 659  total_loss: 0.2995  loss_cls: 0.08161  loss_box_reg: 0.1836  loss_rpn_cls: 0.003455  loss_rpn_loc: 0.02393    time: 0.9325  last_time: 1.3536  data_time: 0.0015  last_data_time: 0.0015   lr: 0.0016484  max_mem: 2320M
# [10/02 11:49:12 d2.utils.events]:  eta: 0:40:28  iter: 679  total_loss: 0.3319  loss_cls: 0.1029  loss_box_reg: 0.1965  loss_rpn_cls: 0.003848  loss_rpn_loc: 0.02884    time: 0.9312  last_time: 1.0403  data_time: 0.0015  last_data_time: 0.0017   lr: 0.0016983  max_mem: 2320M
# [10/02 11:49:12 d2.utils.events]:  eta: 0:40:28  iter: 679  total_loss: 0.3319  loss_cls: 0.1029  loss_box_reg: 0.1965  loss_rpn_cls: 0.003848  loss_rpn_loc: 0.02884    time: 0.9312  last_time: 1.0403  data_time: 0.0015  last_data_time: 0.0017   lr: 0.0016983  max_mem: 2320M
# [10/02 11:49:30 d2.utils.events]:  eta: 0:40:07  iter: 699  total_loss: 0.3254  loss_cls: 0.09947  loss_box_reg: 0.1947  loss_rpn_cls: 0.002926  loss_rpn_loc: 0.02811    time: 0.9304  last_time: 1.1497  data_time: 0.0015  last_data_time: 0.0014   lr: 0.0017483  max_mem: 2320M
# [10/02 11:49:30 d2.utils.events]:  eta: 0:40:07  iter: 699  total_loss: 0.3254  loss_cls: 0.09947  loss_box_reg: 0.1947  loss_rpn_cls: 0.002926  loss_rpn_loc: 0.02811    time: 0.9304  last_time: 1.1497  data_time: 0.0015  last_data_time: 0.0014   lr: 0.0017483  max_mem: 2320M
# [10/02 11:49:46 d2.utils.events]:  eta: 0:39:45  iter: 719  total_loss: 0.277  loss_cls: 0.08013  loss_box_reg: 0.1678  loss_rpn_cls: 0.001359  loss_rpn_loc: 0.02696    time: 0.9277  last_time: 0.7408  data_time: 0.0016  last_data_time: 0.0013   lr: 0.0017982  max_mem: 2320M
# [10/02 11:49:46 d2.utils.events]:  eta: 0:39:45  iter: 719  total_loss: 0.277  loss_cls: 0.08013  loss_box_reg: 0.1678  loss_rpn_cls: 0.001359  loss_rpn_loc: 0.02696    time: 0.9277  last_time: 0.7408  data_time: 0.0016  last_data_time: 0.0013   lr: 0.0017982  max_mem: 2320M
# [10/02 11:50:04 d2.utils.events]:  eta: 0:39:23  iter: 739  total_loss: 0.3032  loss_cls: 0.09756  loss_box_reg: 0.1775  loss_rpn_cls: 0.004528  loss_rpn_loc: 0.03104    time: 0.9262  last_time: 1.0483  data_time: 0.0016  last_data_time: 0.0014   lr: 0.0018482  max_mem: 2321M
# [10/02 11:50:04 d2.utils.events]:  eta: 0:39:23  iter: 739  total_loss: 0.3032  loss_cls: 0.09756  loss_box_reg: 0.1775  loss_rpn_cls: 0.004528  loss_rpn_loc: 0.03104    time: 0.9262  last_time: 1.0483  data_time: 0.0016  last_data_time: 0.0014   lr: 0.0018482  max_mem: 2321M
# [10/02 11:50:23 d2.utils.events]:  eta: 0:39:04  iter: 759  total_loss: 0.2788  loss_cls: 0.07747  loss_box_reg: 0.1775  loss_rpn_cls: 0.002642  loss_rpn_loc: 0.03006    time: 0.9276  last_time: 0.7366  data_time: 0.0015  last_data_time: 0.0014   lr: 0.0018981  max_mem: 2321M
# [10/02 11:50:23 d2.utils.events]:  eta: 0:39:04  iter: 759  total_loss: 0.2788  loss_cls: 0.07747  loss_box_reg: 0.1775  loss_rpn_cls: 0.002642  loss_rpn_loc: 0.03006    time: 0.9276  last_time: 0.7366  data_time: 0.0015  last_data_time: 0.0014   lr: 0.0018981  max_mem: 2321M
# [10/02 11:50:42 d2.utils.events]:  eta: 0:38:43  iter: 779  total_loss: 0.2742  loss_cls: 0.07617  loss_box_reg: 0.1668  loss_rpn_cls: 0.001524  loss_rpn_loc: 0.02349    time: 0.9280  last_time: 0.6737  data_time: 0.0015  last_data_time: 0.0024   lr: 0.0019481  max_mem: 2321M
# [10/02 11:50:42 d2.utils.events]:  eta: 0:38:43  iter: 779  total_loss: 0.2742  loss_cls: 0.07617  loss_box_reg: 0.1668  loss_rpn_cls: 0.001524  loss_rpn_loc: 0.02349    time: 0.9280  last_time: 0.6737  data_time: 0.0015  last_data_time: 0.0024   lr: 0.0019481  max_mem: 2321M
# [10/02 11:51:00 d2.utils.events]:  eta: 0:38:20  iter: 799  total_loss: 0.2986  loss_cls: 0.08504  loss_box_reg: 0.1751  loss_rpn_cls: 0.005445  loss_rpn_loc: 0.02634    time: 0.9268  last_time: 1.1510  data_time: 0.0014  last_data_time: 0.0013   lr: 0.001998  max_mem: 2321M
# [10/02 11:51:00 d2.utils.events]:  eta: 0:38:20  iter: 799  total_loss: 0.2986  loss_cls: 0.08504  loss_box_reg: 0.1751  loss_rpn_cls: 0.005445  loss_rpn_loc: 0.02634    time: 0.9268  last_time: 1.1510  data_time: 0.0014  last_data_time: 0.0013   lr: 0.001998  max_mem: 2321M
# [10/02 11:51:17 d2.utils.events]:  eta: 0:37:58  iter: 819  total_loss: 0.347  loss_cls: 0.09816  loss_box_reg: 0.1995  loss_rpn_cls: 0.003209  loss_rpn_loc: 0.02797    time: 0.9247  last_time: 1.0427  data_time: 0.0015  last_data_time: 0.0015   lr: 0.002048  max_mem: 2321M
# [10/02 11:51:17 d2.utils.events]:  eta: 0:37:58  iter: 819  total_loss: 0.347  loss_cls: 0.09816  loss_box_reg: 0.1995  loss_rpn_cls: 0.003209  loss_rpn_loc: 0.02797    time: 0.9247  last_time: 1.0427  data_time: 0.0015  last_data_time: 0.0015   lr: 0.002048  max_mem: 2321M
# [10/02 11:51:35 d2.utils.events]:  eta: 0:37:38  iter: 839  total_loss: 0.2492  loss_cls: 0.06875  loss_box_reg: 0.1581  loss_rpn_cls: 0.002585  loss_rpn_loc: 0.02644    time: 0.9250  last_time: 1.0358  data_time: 0.0016  last_data_time: 0.0014   lr: 0.0020979  max_mem: 2321M
# [10/02 11:51:35 d2.utils.events]:  eta: 0:37:38  iter: 839  total_loss: 0.2492  loss_cls: 0.06875  loss_box_reg: 0.1581  loss_rpn_cls: 0.002585  loss_rpn_loc: 0.02644    time: 0.9250  last_time: 1.0358  data_time: 0.0016  last_data_time: 0.0014   lr: 0.0020979  max_mem: 2321M
# [10/02 11:51:53 d2.utils.events]:  eta: 0:37:16  iter: 859  total_loss: 0.2615  loss_cls: 0.08061  loss_box_reg: 0.169  loss_rpn_cls: 0.000973  loss_rpn_loc: 0.02476    time: 0.9240  last_time: 1.1455  data_time: 0.0015  last_data_time: 0.0013   lr: 0.0021479  max_mem: 2321M
# [10/02 11:51:53 d2.utils.events]:  eta: 0:37:16  iter: 859  total_loss: 0.2615  loss_cls: 0.08061  loss_box_reg: 0.169  loss_rpn_cls: 0.000973  loss_rpn_loc: 0.02476    time: 0.9240  last_time: 1.1455  data_time: 0.0015  last_data_time: 0.0013   lr: 0.0021479  max_mem: 2321M
# [10/02 11:52:12 d2.utils.events]:  eta: 0:36:56  iter: 879  total_loss: 0.3131  loss_cls: 0.08338  loss_box_reg: 0.1966  loss_rpn_cls: 0.005143  loss_rpn_loc: 0.03404    time: 0.9248  last_time: 1.0522  data_time: 0.0015  last_data_time: 0.0013   lr: 0.0021978  max_mem: 2321M
# [10/02 11:52:12 d2.utils.events]:  eta: 0:36:56  iter: 879  total_loss: 0.3131  loss_cls: 0.08338  loss_box_reg: 0.1966  loss_rpn_cls: 0.005143  loss_rpn_loc: 0.03404    time: 0.9248  last_time: 1.0522  data_time: 0.0015  last_data_time: 0.0013   lr: 0.0021978  max_mem: 2321M
# [10/02 11:52:31 d2.utils.events]:  eta: 0:36:35  iter: 899  total_loss: 0.3109  loss_cls: 0.07674  loss_box_reg: 0.1907  loss_rpn_cls: 0.003517  loss_rpn_loc: 0.02863    time: 0.9253  last_time: 0.7309  data_time: 0.0036  last_data_time: 0.0014   lr: 0.0022478  max_mem: 2321M
# [10/02 11:52:31 d2.utils.events]:  eta: 0:36:35  iter: 899  total_loss: 0.3109  loss_cls: 0.07674  loss_box_reg: 0.1907  loss_rpn_cls: 0.003517  loss_rpn_loc: 0.02863    time: 0.9253  last_time: 0.7309  data_time: 0.0036  last_data_time: 0.0014   lr: 0.0022478  max_mem: 2321M
# [10/02 11:52:50 d2.utils.events]:  eta: 0:36:14  iter: 919  total_loss: 0.272  loss_cls: 0.07355  loss_box_reg: 0.1645  loss_rpn_cls: 0.002798  loss_rpn_loc: 0.02526    time: 0.9256  last_time: 0.6809  data_time: 0.0015  last_data_time: 0.0013   lr: 0.0022977  max_mem: 2321M
# [10/02 11:52:50 d2.utils.events]:  eta: 0:36:14  iter: 919  total_loss: 0.272  loss_cls: 0.07355  loss_box_reg: 0.1645  loss_rpn_cls: 0.002798  loss_rpn_loc: 0.02526    time: 0.9256  last_time: 0.6809  data_time: 0.0015  last_data_time: 0.0013   lr: 0.0022977  max_mem: 2321M
# [10/02 11:53:09 d2.utils.events]:  eta: 0:35:53  iter: 939  total_loss: 0.2975  loss_cls: 0.07374  loss_box_reg: 0.1938  loss_rpn_cls: 0.00298  loss_rpn_loc: 0.02422    time: 0.9256  last_time: 0.6600  data_time: 0.0014  last_data_time: 0.0013   lr: 0.0023477  max_mem: 2321M
# [10/02 11:53:09 d2.utils.events]:  eta: 0:35:53  iter: 939  total_loss: 0.2975  loss_cls: 0.07374  loss_box_reg: 0.1938  loss_rpn_cls: 0.00298  loss_rpn_loc: 0.02422    time: 0.9256  last_time: 0.6600  data_time: 0.0014  last_data_time: 0.0013   lr: 0.0023477  max_mem: 2321M
# [10/02 11:53:25 d2.utils.events]:  eta: 0:35:32  iter: 959  total_loss: 0.3251  loss_cls: 0.09066  loss_box_reg: 0.1961  loss_rpn_cls: 0.003748  loss_rpn_loc: 0.03315    time: 0.9236  last_time: 0.6654  data_time: 0.0014  last_data_time: 0.0011   lr: 0.0023976  max_mem: 2321M
# [10/02 11:53:25 d2.utils.events]:  eta: 0:35:32  iter: 959  total_loss: 0.3251  loss_cls: 0.09066  loss_box_reg: 0.1961  loss_rpn_cls: 0.003748  loss_rpn_loc: 0.03315    time: 0.9236  last_time: 0.6654  data_time: 0.0014  last_data_time: 0.0011   lr: 0.0023976  max_mem: 2321M
# [10/02 11:53:43 d2.utils.events]:  eta: 0:35:11  iter: 979  total_loss: 0.297  loss_cls: 0.08277  loss_box_reg: 0.1818  loss_rpn_cls: 0.002627  loss_rpn_loc: 0.02824    time: 0.9232  last_time: 1.1397  data_time: 0.0015  last_data_time: 0.0014   lr: 0.0024476  max_mem: 2321M
# [10/02 11:53:43 d2.utils.events]:  eta: 0:35:11  iter: 979  total_loss: 0.297  loss_cls: 0.08277  loss_box_reg: 0.1818  loss_rpn_cls: 0.002627  loss_rpn_loc: 0.02824    time: 0.9232  last_time: 1.1397  data_time: 0.0015  last_data_time: 0.0014   lr: 0.0024476  max_mem: 2321M
# [10/02 11:54:03 d2.data.datasets.coco]: Loaded 60 images in COCO format from e:\B3\group_prj\characters-and-dialouges-association-in-comics\data\Manga109\Human_Annotate_300\val.json
# [10/02 11:54:03 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [10/02 11:54:03 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/02 11:54:03 d2.data.common]: Serializing 60 elements to byte tensors and concatenating them all ...
# [10/02 11:54:03 d2.data.common]: Serialized dataset takes 0.03 MiB
# WARNING [10/02 11:54:03 d2.engine.defaults]: No evaluator found. Use `DefaultTrainer.test(evaluators=)`, or implement its `build_evaluator` method.
# [10/02 11:54:03 d2.utils.events]:  eta: 0:34:50  iter: 999  total_loss: 0.2945  loss_cls: 0.08419  loss_box_reg: 0.1699  loss_rpn_cls: 0.002344  loss_rpn_loc: 0.02666    time: 0.9246  last_time: 0.8684  data_time: 0.0015  last_data_time: 0.0013   lr: 0.0024975  max_mem: 2321M
# [10/02 11:54:03 d2.data.datasets.coco]: Loaded 60 images in COCO format from e:\B3\group_prj\characters-and-dialouges-association-in-comics\data\Manga109\Human_Annotate_300\val.json
# [10/02 11:54:03 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [10/02 11:54:03 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/02 11:54:03 d2.data.common]: Serializing 60 elements to byte tensors and concatenating them all ...
# [10/02 11:54:03 d2.data.common]: Serialized dataset takes 0.03 MiB
# ...
# [10/02 12:17:03 d2.utils.events]:  eta: 0:08:40  iter: 2499  total_loss: 0.223  loss_cls: 0.0647  loss_box_reg: 0.1372  loss_rpn_cls: 0.001007  loss_rpn_loc: 0.02122    time: 0.9214  last_time: 0.6041  data_time: 0.0015  last_data_time: 0.0014   lr: 0.0025  max_mem: 2321M
# [10/02 12:17:21 d2.utils.events]:  eta: 0:08:20  iter: 2519  total_loss: 0.2276  loss_cls: 0.05681  loss_box_reg: 0.1413  loss_rpn_cls: 0.001002  loss_rpn_loc: 0.02131    time: 0.9211  last_time: 1.1372  data_time: 0.0015  last_data_time: 0.0013   lr: 0.0025  max_mem: 2321M
# [10/02 12:17:21 d2.utils.events]:  eta: 0:08:20  iter: 2519  total_loss: 0.2276  loss_cls: 0.05681  loss_box_reg: 0.1413  loss_rpn_cls: 0.001002  loss_rpn_loc: 0.02131    time: 0.9211  last_time: 1.1372  data_time: 0.0015  last_data_time: 0.0013   lr: 0.0025  max_mem: 2321M
# [10/02 12:17:39 d2.utils.events]:  eta: 0:07:59  iter: 2539  total_loss: 0.2249  loss_cls: 0.05712  loss_box_reg: 0.1411  loss_rpn_cls: 0.001482  loss_rpn_loc: 0.02035    time: 0.9210  last_time: 1.0398  data_time: 0.0015  last_data_time: 0.0013   lr: 0.0025  max_mem: 2321M
# [10/02 12:17:39 d2.utils.events]:  eta: 0:07:59  iter: 2539  total_loss: 0.2249  loss_cls: 0.05712  loss_box_reg: 0.1411  loss_rpn_cls: 0.001482  loss_rpn_loc: 0.02035    time: 0.9210  last_time: 1.0398  data_time: 0.0015  last_data_time: 0.0013   lr: 0.0025  max_mem: 2321M
# [10/02 12:17:58 d2.utils.events]:  eta: 0:07:38  iter: 2559  total_loss: 0.2022  loss_cls: 0.056  loss_box_reg: 0.1214  loss_rpn_cls: 0.001053  loss_rpn_loc: 0.01698    time: 0.9211  last_time: 0.6608  data_time: 0.0016  last_data_time: 0.0014   lr: 0.0025  max_mem: 2321M
# [10/02 12:17:58 d2.utils.events]:  eta: 0:07:38  iter: 2559  total_loss: 0.2022  loss_cls: 0.056  loss_box_reg: 0.1214  loss_rpn_cls: 0.001053  loss_rpn_loc: 0.01698    time: 0.9211  last_time: 0.6608  data_time: 0.0016  last_data_time: 0.0014   lr: 0.0025  max_mem: 2321M
# [10/02 12:18:15 d2.utils.events]:  eta: 0:07:17  iter: 2579  total_loss: 0.2074  loss_cls: 0.06915  loss_box_reg: 0.1274  loss_rpn_cls: 0.0007814  loss_rpn_loc: 0.01943    time: 0.9205  last_time: 0.7374  data_time: 0.0015  last_data_time: 0.0013   lr: 0.0025  max_mem: 2321M
# [10/02 12:18:15 d2.utils.events]:  eta: 0:07:17  iter: 2579  total_loss: 0.2074  loss_cls: 0.06915  loss_box_reg: 0.1274  loss_rpn_cls: 0.0007814  loss_rpn_loc: 0.01943    time: 0.9205  last_time: 0.7374  data_time: 0.0015  last_data_time: 0.0013   lr: 0.0025  max_mem: 2321M
# [10/02 12:18:34 d2.utils.events]:  eta: 0:06:56  iter: 2599  total_loss: 0.2219  loss_cls: 0.06619  loss_box_reg: 0.13  loss_rpn_cls: 0.0007783  loss_rpn_loc: 0.01782    time: 0.9210  last_time: 0.8598  data_time: 0.0015  last_data_time: 0.0013   lr: 0.0025  max_mem: 2321M
# [10/02 12:18:34 d2.utils.events]:  eta: 0:06:56  iter: 2599  total_loss: 0.2219  loss_cls: 0.06619  loss_box_reg: 0.13  loss_rpn_cls: 0.0007783  loss_rpn_loc: 0.01782    time: 0.9210  last_time: 0.8598  data_time: 0.0015  last_data_time: 0.0013   lr: 0.0025  max_mem: 2321M
# [10/02 12:18:54 d2.utils.events]:  eta: 0:06:35  iter: 2619  total_loss: 0.2312  loss_cls: 0.06489  loss_box_reg: 0.1374  loss_rpn_cls: 0.0008683  loss_rpn_loc: 0.02499    time: 0.9214  last_time: 1.0386  data_time: 0.0016  last_data_time: 0.0012   lr: 0.0025  max_mem: 2321M
# [10/02 12:18:54 d2.utils.events]:  eta: 0:06:35  iter: 2619  total_loss: 0.2312  loss_cls: 0.06489  loss_box_reg: 0.1374  loss_rpn_cls: 0.0008683  loss_rpn_loc: 0.02499    time: 0.9214  last_time: 1.0386  data_time: 0.0016  last_data_time: 0.0012   lr: 0.0025  max_mem: 2321M
# [10/02 12:19:11 d2.utils.events]:  eta: 0:06:15  iter: 2639  total_loss: 0.2099  loss_cls: 0.05132  loss_box_reg: 0.1308  loss_rpn_cls: 0.001165  loss_rpn_loc: 0.02288    time: 0.9209  last_time: 0.7347  data_time: 0.0015  last_data_time: 0.0014   lr: 0.0025  max_mem: 2321M
# [10/02 12:19:11 d2.utils.events]:  eta: 0:06:15  iter: 2639  total_loss: 0.2099  loss_cls: 0.05132  loss_box_reg: 0.1308  loss_rpn_cls: 0.001165  loss_rpn_loc: 0.02288    time: 0.9209  last_time: 0.7347  data_time: 0.0015  last_data_time: 0.0014   lr: 0.0025  max_mem: 2321M
# [10/02 12:19:30 d2.utils.events]:  eta: 0:05:54  iter: 2659  total_loss: 0.208  loss_cls: 0.05074  loss_box_reg: 0.1345  loss_rpn_cls: 0.0009205  loss_rpn_loc: 0.02084    time: 0.9212  last_time: 0.7312  data_time: 0.0016  last_data_time: 0.0014   lr: 0.0025  max_mem: 2321M
# [10/02 12:19:30 d2.utils.events]:  eta: 0:05:54  iter: 2659  total_loss: 0.208  loss_cls: 0.05074  loss_box_reg: 0.1345  loss_rpn_cls: 0.0009205  loss_rpn_loc: 0.02084    time: 0.9212  last_time: 0.7312  data_time: 0.0016  last_data_time: 0.0014   lr: 0.0025  max_mem: 2321M
# [10/02 12:19:49 d2.utils.events]:  eta: 0:05:33  iter: 2679  total_loss: 0.1876  loss_cls: 0.0429  loss_box_reg: 0.1206  loss_rpn_cls: 0.0008196  loss_rpn_loc: 0.02056    time: 0.9212  last_time: 1.1355  data_time: 0.0015  last_data_time: 0.0015   lr: 0.0025  max_mem: 2321M
# [10/02 12:19:49 d2.utils.events]:  eta: 0:05:33  iter: 2679  total_loss: 0.1876  loss_cls: 0.0429  loss_box_reg: 0.1206  loss_rpn_cls: 0.0008196  loss_rpn_loc: 0.02056    time: 0.9212  last_time: 1.1355  data_time: 0.0015  last_data_time: 0.0015   lr: 0.0025  max_mem: 2321M
# [10/02 12:20:08 d2.utils.events]:  eta: 0:05:12  iter: 2699  total_loss: 0.1875  loss_cls: 0.04488  loss_box_reg: 0.1302  loss_rpn_cls: 0.0009328  loss_rpn_loc: 0.01557    time: 0.9214  last_time: 1.1364  data_time: 0.0016  last_data_time: 0.0012   lr: 0.0025  max_mem: 2321M
# [10/02 12:20:08 d2.utils.events]:  eta: 0:05:12  iter: 2699  total_loss: 0.1875  loss_cls: 0.04488  loss_box_reg: 0.1302  loss_rpn_cls: 0.0009328  loss_rpn_loc: 0.01557    time: 0.9214  last_time: 1.1364  data_time: 0.0016  last_data_time: 0.0012   lr: 0.0025  max_mem: 2321M
# [10/02 12:20:27 d2.utils.events]:  eta: 0:04:51  iter: 2719  total_loss: 0.209  loss_cls: 0.05888  loss_box_reg: 0.128  loss_rpn_cls: 0.0006481  loss_rpn_loc: 0.02119    time: 0.9216  last_time: 1.1368  data_time: 0.0015  last_data_time: 0.0014   lr: 0.0025  max_mem: 2321M
# [10/02 12:20:27 d2.utils.events]:  eta: 0:04:51  iter: 2719  total_loss: 0.209  loss_cls: 0.05888  loss_box_reg: 0.128  loss_rpn_cls: 0.0006481  loss_rpn_loc: 0.02119    time: 0.9216  last_time: 1.1368  data_time: 0.0015  last_data_time: 0.0014   lr: 0.0025  max_mem: 2321M
# [10/02 12:20:45 d2.utils.events]:  eta: 0:04:30  iter: 2739  total_loss: 0.1933  loss_cls: 0.05423  loss_box_reg: 0.12  loss_rpn_cls: 0.00105  loss_rpn_loc: 0.01919    time: 0.9214  last_time: 0.7282  data_time: 0.0014  last_data_time: 0.0014   lr: 0.0025  max_mem: 2321M
# [10/02 12:20:45 d2.utils.events]:  eta: 0:04:30  iter: 2739  total_loss: 0.1933  loss_cls: 0.05423  loss_box_reg: 0.12  loss_rpn_cls: 0.00105  loss_rpn_loc: 0.01919    time: 0.9214  last_time: 0.7282  data_time: 0.0014  last_data_time: 0.0014   lr: 0.0025  max_mem: 2321M
# [10/02 12:21:02 d2.utils.events]:  eta: 0:04:10  iter: 2759  total_loss: 0.2064  loss_cls: 0.05326  loss_box_reg: 0.133  loss_rpn_cls: 0.0008148  loss_rpn_loc: 0.01973    time: 0.9209  last_time: 1.1330  data_time: 0.0014  last_data_time: 0.0017   lr: 0.0025  max_mem: 2321M
# [10/02 12:21:02 d2.utils.events]:  eta: 0:04:10  iter: 2759  total_loss: 0.2064  loss_cls: 0.05326  loss_box_reg: 0.133  loss_rpn_cls: 0.0008148  loss_rpn_loc: 0.01973    time: 0.9209  last_time: 1.1330  data_time: 0.0014  last_data_time: 0.0017   lr: 0.0025  max_mem: 2321M
# [10/02 12:21:20 d2.utils.events]:  eta: 0:03:49  iter: 2779  total_loss: 0.2179  loss_cls: 0.0618  loss_box_reg: 0.1347  loss_rpn_cls: 0.001072  loss_rpn_loc: 0.02114    time: 0.9209  last_time: 1.0449  data_time: 0.0014  last_data_time: 0.0014   lr: 0.0025  max_mem: 2321M
# [10/02 12:21:20 d2.utils.events]:  eta: 0:03:49  iter: 2779  total_loss: 0.2179  loss_cls: 0.0618  loss_box_reg: 0.1347  loss_rpn_cls: 0.001072  loss_rpn_loc: 0.02114    time: 0.9209  last_time: 1.0449  data_time: 0.0014  last_data_time: 0.0014   lr: 0.0025  max_mem: 2321M
# [10/02 12:21:37 d2.utils.events]:  eta: 0:03:28  iter: 2799  total_loss: 0.2184  loss_cls: 0.05596  loss_box_reg: 0.1333  loss_rpn_cls: 0.001027  loss_rpn_loc: 0.02266    time: 0.9203  last_time: 1.0476  data_time: 0.0014  last_data_time: 0.0013   lr: 0.0025  max_mem: 2321M
# [10/02 12:21:37 d2.utils.events]:  eta: 0:03:28  iter: 2799  total_loss: 0.2184  loss_cls: 0.05596  loss_box_reg: 0.1333  loss_rpn_cls: 0.001027  loss_rpn_loc: 0.02266    time: 0.9203  last_time: 1.0476  data_time: 0.0014  last_data_time: 0.0013   lr: 0.0025  max_mem: 2321M
# [10/02 12:21:56 d2.utils.events]:  eta: 0:03:07  iter: 2819  total_loss: 0.2051  loss_cls: 0.04963  loss_box_reg: 0.1304  loss_rpn_cls: 0.0006894  loss_rpn_loc: 0.01662    time: 0.9207  last_time: 0.6921  data_time: 0.0016  last_data_time: 0.0014   lr: 0.0025  max_mem: 2321M
# [10/02 12:21:56 d2.utils.events]:  eta: 0:03:07  iter: 2819  total_loss: 0.2051  loss_cls: 0.04963  loss_box_reg: 0.1304  loss_rpn_cls: 0.0006894  loss_rpn_loc: 0.01662    time: 0.9207  last_time: 0.6921  data_time: 0.0016  last_data_time: 0.0014   lr: 0.0025  max_mem: 2321M
# [10/02 12:22:15 d2.utils.events]:  eta: 0:02:46  iter: 2839  total_loss: 0.2313  loss_cls: 0.05455  loss_box_reg: 0.1376  loss_rpn_cls: 0.0009539  loss_rpn_loc: 0.02569    time: 0.9207  last_time: 1.0494  data_time: 0.0015  last_data_time: 0.0013   lr: 0.0025  max_mem: 2321M
# [10/02 12:22:15 d2.utils.events]:  eta: 0:02:46  iter: 2839  total_loss: 0.2313  loss_cls: 0.05455  loss_box_reg: 0.1376  loss_rpn_cls: 0.0009539  loss_rpn_loc: 0.02569    time: 0.9207  last_time: 1.0494  data_time: 0.0015  last_data_time: 0.0013   lr: 0.0025  max_mem: 2321M
# [10/02 12:22:33 d2.utils.events]:  eta: 0:02:25  iter: 2859  total_loss: 0.1971  loss_cls: 0.04692  loss_box_reg: 0.1196  loss_rpn_cls: 0.0005438  loss_rpn_loc: 0.01634    time: 0.9207  last_time: 1.1336  data_time: 0.0015  last_data_time: 0.0013   lr: 0.0025  max_mem: 2321M
# [10/02 12:22:33 d2.utils.events]:  eta: 0:02:25  iter: 2859  total_loss: 0.1971  loss_cls: 0.04692  loss_box_reg: 0.1196  loss_rpn_cls: 0.0005438  loss_rpn_loc: 0.01634    time: 0.9207  last_time: 1.1336  data_time: 0.0015  last_data_time: 0.0013   lr: 0.0025  max_mem: 2321M
# [10/02 12:22:52 d2.utils.events]:  eta: 0:02:05  iter: 2879  total_loss: 0.2034  loss_cls: 0.05377  loss_box_reg: 0.1298  loss_rpn_cls: 0.0009348  loss_rpn_loc: 0.02263    time: 0.9207  last_time: 1.1425  data_time: 0.0016  last_data_time: 0.0015   lr: 0.0025  max_mem: 2321M
# [10/02 12:22:52 d2.utils.events]:  eta: 0:02:05  iter: 2879  total_loss: 0.2034  loss_cls: 0.05377  loss_box_reg: 0.1298  loss_rpn_cls: 0.0009348  loss_rpn_loc: 0.02263    time: 0.9207  last_time: 1.1425  data_time: 0.0016  last_data_time: 0.0015   lr: 0.0025  max_mem: 2321M
# [10/02 12:23:11 d2.utils.events]:  eta: 0:01:44  iter: 2899  total_loss: 0.2279  loss_cls: 0.0584  loss_box_reg: 0.139  loss_rpn_cls: 0.0008379  loss_rpn_loc: 0.02564    time: 0.9211  last_time: 0.8548  data_time: 0.0017  last_data_time: 0.0013   lr: 0.0025  max_mem: 2321M
# [10/02 12:23:11 d2.utils.events]:  eta: 0:01:44  iter: 2899  total_loss: 0.2279  loss_cls: 0.0584  loss_box_reg: 0.139  loss_rpn_cls: 0.0008379  loss_rpn_loc: 0.02564    time: 0.9211  last_time: 0.8548  data_time: 0.0017  last_data_time: 0.0013   lr: 0.0025  max_mem: 2321M
# [10/02 12:23:28 d2.utils.events]:  eta: 0:01:23  iter: 2919  total_loss: 0.2016  loss_cls: 0.05665  loss_box_reg: 0.1194  loss_rpn_cls: 0.001342  loss_rpn_loc: 0.0222    time: 0.9204  last_time: 1.1298  data_time: 0.0016  last_data_time: 0.0017   lr: 0.0025  max_mem: 2321M
# [10/02 12:23:28 d2.utils.events]:  eta: 0:01:23  iter: 2919  total_loss: 0.2016  loss_cls: 0.05665  loss_box_reg: 0.1194  loss_rpn_cls: 0.001342  loss_rpn_loc: 0.0222    time: 0.9204  last_time: 1.1298  data_time: 0.0016  last_data_time: 0.0017   lr: 0.0025  max_mem: 2321M
# [10/02 12:23:46 d2.utils.events]:  eta: 0:01:02  iter: 2939  total_loss: 0.197  loss_cls: 0.052  loss_box_reg: 0.1263  loss_rpn_cls: 0.001326  loss_rpn_loc: 0.01888    time: 0.9203  last_time: 1.1427  data_time: 0.0015  last_data_time: 0.0015   lr: 0.0025  max_mem: 2321M
# [10/02 12:23:46 d2.utils.events]:  eta: 0:01:02  iter: 2939  total_loss: 0.197  loss_cls: 0.052  loss_box_reg: 0.1263  loss_rpn_cls: 0.001326  loss_rpn_loc: 0.01888    time: 0.9203  last_time: 1.1427  data_time: 0.0015  last_data_time: 0.0015   lr: 0.0025  max_mem: 2321M
# [10/02 12:24:05 d2.utils.events]:  eta: 0:00:41  iter: 2959  total_loss: 0.1943  loss_cls: 0.04459  loss_box_reg: 0.1248  loss_rpn_cls: 0.001136  loss_rpn_loc: 0.02053    time: 0.9205  last_time: 0.7340  data_time: 0.0016  last_data_time: 0.0013   lr: 0.0025  max_mem: 2321M
# [10/02 12:24:05 d2.utils.events]:  eta: 0:00:41  iter: 2959  total_loss: 0.1943  loss_cls: 0.04459  loss_box_reg: 0.1248  loss_rpn_cls: 0.001136  loss_rpn_loc: 0.02053    time: 0.9205  last_time: 0.7340  data_time: 0.0016  last_data_time: 0.0013   lr: 0.0025  max_mem: 2321M
# [10/02 12:24:23 d2.utils.events]:  eta: 0:00:20  iter: 2979  total_loss: 0.1795  loss_cls: 0.04919  loss_box_reg: 0.1171  loss_rpn_cls: 0.0009951  loss_rpn_loc: 0.01725    time: 0.9204  last_time: 0.6160  data_time: 0.0016  last_data_time: 0.0014   lr: 0.0025  max_mem: 2321M
# [10/02 12:24:23 d2.utils.events]:  eta: 0:00:20  iter: 2979  total_loss: 0.1795  loss_cls: 0.04919  loss_box_reg: 0.1171  loss_rpn_cls: 0.0009951  loss_rpn_loc: 0.01725    time: 0.9204  last_time: 0.6160  data_time: 0.0016  last_data_time: 0.0014   lr: 0.0025  max_mem: 2321M
# [10/02 12:24:42 d2.utils.events]:  eta: 0:00:00  iter: 2999  total_loss: 0.1872  loss_cls: 0.04879  loss_box_reg: 0.1158  loss_rpn_cls: 0.0006245  loss_rpn_loc: 0.01496    time: 0.9205  last_time: 1.0478  data_time: 0.0015  last_data_time: 0.0012   lr: 0.0025  max_mem: 2321M
# [10/02 12:24:42 d2.engine.hooks]: Overall training speed: 2998 iterations in 0:45:59 (0.9205 s / it)
# [10/02 12:24:42 d2.engine.hooks]: Total training time: 0:46:02 (0:00:02 on hooks)
# [10/02 12:24:42 d2.data.datasets.coco]: Loaded 60 images in COCO format from e:\B3\group_prj\characters-and-dialouges-association-in-comics\data\Manga109\Human_Annotate_300\val.json
# [10/02 12:24:42 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [10/02 12:24:42 d2.utils.events]:  eta: 0:00:00  iter: 2999  total_loss: 0.1872  loss_cls: 0.04879  loss_box_reg: 0.1158  loss_rpn_cls: 0.0006245  loss_rpn_loc: 0.01496    time: 0.9205  last_time: 1.0478  data_time: 0.0015  last_data_time: 0.0012   lr: 0.0025  max_mem: 2321M
# [10/02 12:24:42 d2.engine.hooks]: Overall training speed: 2998 iterations in 0:45:59 (0.9205 s / it)
# [10/02 12:24:42 d2.engine.hooks]: Total training time: 0:46:02 (0:00:02 on hooks)
# [10/02 12:24:42 d2.data.datasets.coco]: Loaded 60 images in COCO format from e:\B3\group_prj\characters-and-dialouges-association-in-comics\data\Manga109\Human_Annotate_300\val.json
# [10/02 12:24:42 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [10/02 12:24:42 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/02 12:24:42 d2.data.common]: Serializing 60 elements to byte tensors and concatenating them all ...
# [10/02 12:24:42 d2.data.common]: Serialized dataset takes 0.03 MiB
# WARNING [10/02 12:24:42 d2.engine.defaults]: No evaluator found. Use `DefaultTrainer.test(evaluators=)`, or implement its `build_evaluator` method.
# [10/02 12:24:42 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [10/02 12:24:42 d2.data.common]: Serializing 60 elements to byte tensors and concatenating them all ...
# [10/02 12:24:42 d2.data.common]: Serialized dataset takes 0.03 MiB
# WARNING [10/02 12:24:42 d2.engine.defaults]: No evaluator found. Use `DefaultTrainer.test(evaluators=)`, or implement its `build_evaluator` method.

# %%
from detectron2.engine import DefaultPredictor
from detectron2.utils.visualizer import Visualizer, ColorMode

# --- Setup the predictor ---
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")  # Path to your trained model
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.7  # Set a threshold for predictions
predictor = DefaultPredictor(cfg)

# Get the metadata and the list of data dictionaries for the validation set
val_metadata = MetadataCatalog.get("manga109_val")
dataset_dicts = DatasetCatalog.get("manga109_val")

# Randomly select a few images from the validation set to visualize
num_images_to_show = 3
for d in random.sample(dataset_dicts, num_images_to_show):    
    im = cv2.imread(d["file_name"])
    if im is None:
        print(f"Warning: Could not read image {d['file_name']}. Skipping.")
        continue

    # Make predictions
    outputs = predictor(im)

    # --- Visualize Predictions ---
    v_pred = Visualizer(im[:, :, ::-1],
                   metadata=val_metadata, 
                   scale=0.8,
                   instance_mode=ColorMode.IMAGE_BW # or ColorMode.IMAGE
    )
    predictions_vis = v_pred.draw_instance_predictions(outputs["instances"].to("cpu"))

    # --- Visualize Ground Truth ---
    v_gt = Visualizer(im[:, :, ::-1],
                   metadata=val_metadata, 
                   scale=0.8
    )
    ground_truth_vis = v_gt.draw_dataset_dict(d)

    # --- Display side-by-side ---
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))
    
    ax1.imshow(predictions_vis.get_image()[:, :, ::-1])
    ax1.set_title("Model Predictions")
    ax1.axis("off")

    ax2.imshow(ground_truth_vis.get_image()[:, :, ::-1])
    ax2.set_title("Ground Truth")
    ax2.axis("off")
    
    plt.tight_layout()
    plt.show()
# Out:
# [10/02 12:34:30 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from e:\B3\group_prj\characters-and-dialouges-association-in-comics\models\bubble-detection\detectron2\model_final.pth ...
# [10/02 12:34:30 d2.data.datasets.coco]: Loaded 60 images in COCO format from e:\B3\group_prj\characters-and-dialouges-association-in-comics\data\Manga109\Human_Annotate_300\val.json
# [10/02 12:34:30 d2.data.datasets.coco]: Loaded 60 images in COCO format from e:\B3\group_prj\characters-and-dialouges-association-in-comics\data\Manga109\Human_Annotate_300\val.json
# Warning: Could not read image e:\B3\group_prj\characters-and-dialouges-association-in-comics\data\Manga109\Human_Annotate_300\train\Arisa\001.jpg. Skipping.
# Warning: Could not read image e:\B3\group_prj\characters-and-dialouges-association-in-comics\data\Manga109\Human_Annotate_300\train\Arisa\001.jpg. Skipping.
